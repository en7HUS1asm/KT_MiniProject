# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계3 : 단계별 모델링

# %% [markdown]
# ## 0.미션

# %% [markdown]
# 단계별로 나눠서 모델링을 수행하고자 합니다.
#
# * 단계1 : 정적(0), 동적(1) 행동 분류 모델 생성
# * 단계2 : 세부 동작에 대한 분류모델 생성
#     * 단계1 모델에서 0으로 예측 -> 정적 행동 3가지 분류 모델링
#     * 단계1 모델에서 1으로 예측 -> 동적 행동 3가지 분류 모델링
# * 모델 통합
#     * 두 단계 모델을 통합하고, 새로운 데이터에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
# * 성능 비교
#     * 기본 모델링의 성능과 비교
#     * 모든 모델링은 [다양한 알고리즘 + 성능 튜닝]을 수행해야 합니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 라이브러리 불러오기

# %% [markdown]
# * 세부 요구사항
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#     - 필요하다고 판단되는 라이브러리를 추가하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 필요하다고 판단되는 라이브러리를 추가하세요.

import tensorflow as tf
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (2) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#
#  <br/>
#
# * 세부 요구사항
#     - data01_train.csv 를 불러와 'data' 이름으로 저장합니다.
#         - data에서 변수 subject는 삭제합니다.
#     - data01_test.csv 를 불러와 'new_data' 이름으로 저장합니다.

# %%
data = pd.read_csv('/content/drive/MyDrive/AIVLE/0412-0414/data01_train.csv')
data = data.drop('subject', axis=1)

# %%
new_data = pd.read_csv('/content/drive/MyDrive/AIVLE/0412-0414/data01_train.csv')

#일단은 임시로 train다시대입

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# * 세부 요구사항
#     - Label 추가 : data 에 Activity_dynamic 를 추가합니다. Activity_dynamic은 과제1에서 is_dynamic과 동일한 값입니다.
#     - x와 y1, y2로 분할하시오.
#         * y1 : Activity
#         * y2 : Activity_dynamic
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %% [markdown]
#  **세부 요구사항**
#     - Target인 Activity를 is_dynamic 변수로 변경하시오.
#         * 값 0 : STANDING, SITTING, LAYING
#         * 값 1 : WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS
#     - is_dynamic을 예측하기 위한 기본 모델을 생성하시오.
#         * x, is_dynamic을 이용하여 train과 validation으로 데이터 분할
#         * 기본 모델링
#     - is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석하시오.
#     - is_dynamic 을 구분하는데 중요한 변수 그룹을 분석하시오.
#         * sensor별
#         * sensor+agg 별

# %%
target = 'Activity'

# %%
data[target]
# Out:
# 0                 STANDING
# 1                   LAYING
# 2                 STANDING
# 3                  WALKING
# 4       WALKING_DOWNSTAIRS
#                ...
# 5876               SITTING
# 5877      WALKING_UPSTAIRS
# 5878                LAYING
# 5879      WALKING_UPSTAIRS
# 5880               SITTING
# Name: Activity, Length: 5881, dtype: object

# %%
data['Activity_dynamic'] = data[target]

# %%
data['Activity_dynamic']
# Out:
# 0                 STANDING
# 1                   LAYING
# 2                 STANDING
# 3                  WALKING
# 4       WALKING_DOWNSTAIRS
#                ...
# 5876               SITTING
# 5877      WALKING_UPSTAIRS
# 5878                LAYING
# 5879      WALKING_UPSTAIRS
# 5880               SITTING
# Name: Activity_dynamic, Length: 5881, dtype: object

# %%
data['Activity_dynamic'] = data['Activity_dynamic'].replace('STANDING', 0)
data['Activity_dynamic'] = data['Activity_dynamic'].replace('SITTING', 0)
data['Activity_dynamic'] = data['Activity_dynamic'].replace('LAYING', 0)
data['Activity_dynamic'] = data['Activity_dynamic'].replace('WALKING', 1)
data['Activity_dynamic'] = data['Activity_dynamic'].replace('WALKING_UPSTAIRS', 1)
data['Activity_dynamic'] = data['Activity_dynamic'].replace('WALKING_DOWNSTAIRS', 1)

# %%
data['Activity_dynamic'].value_counts(), data['Activity'].value_counts()
# Out:
# (0    3234
#  1    2647
#  Name: Activity_dynamic, dtype: int64,
#  LAYING                1115
#  STANDING              1087
#  SITTING               1032
#  WALKING                998
#  WALKING_UPSTAIRS       858
#  WALKING_DOWNSTAIRS     791
#  Name: Activity, dtype: int64)

# %%
X = data.drop([target, 'Activity_dynamic'], axis=1)

# %%
Y1 = data[target]
Y2 = data['Activity_dynamic']

# %%
X.shape, Y1.shape, Y2.shape
# Out:
# ((5881, 561), (5881,), (5881,))

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, val_X, train_Y1, val_Y1, train_Y2, val_Y2 =\
    train_test_split(X, Y1, Y2, stratify=Y1, random_state=42, test_size=0.2)

# %%
train_X.shape, train_Y1.shape, train_Y2.shape, val_X.shape, val_Y1.shape, val_Y2.shape
# Out:
# ((4704, 561), (4704,), (4704,), (1177, 561), (1177,), (1177,))

# %% [markdown]
# ## **3.단계별 모델링**

# %% [markdown]
# ![](https://github.com/DA4BAM/image/blob/main/step%20by%20step.png?raw=true)

# %% [markdown]
# ### (1) 단계1 : 정적/동적 행동 분류 모델

# %% [markdown]
# * 세부 요구사항
#     * 정적 행동(Laying, Sitting, Standing)과 동적 행동(동적 : Walking, Walking-Up, Walking-Down)을 구분하는 모델 생성.
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %% [markdown]
# #### 1) 알고리즘1 :

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
knn = KNeighborsClassifier()
knn.fit(train_X, train_Y2)
pred_Y = knn.predict(val_X)
knn.score(val_X, val_Y2)
# Out:
# 0.9991503823279524

# %% [markdown]
# #### 2) 알고리즘2 :

# %%
from tensorflow.keras.utils import to_categorical

# %%
class_n2 = len(set(train_Y2))

train_Y2 = to_categorical(train_Y2, class_n2)
val_Y2 = to_categorical(val_Y2, class_n2)

# %%
train_Y2.shape, val_Y2.shape
# Out:
# ((4704, 2), (1177, 2))

# %%
train_X.shape
# Out:
# (4704, 561)

# %%
# 세션 클리어
keras.backend.clear_session()

# 레이어 엮기
il = keras.layers.Input(shape=(561,))

hl = keras.layers.Dense(1024, activation='relu',)(il)
hl = keras.layers.Dense(512, activation='relu',)(il)
hl = keras.layers.Dense(256, activation='relu',)(il)
hl = keras.layers.Dense(256, activation='relu',)(il)
hl = keras.layers.Dense(128, activation='relu',)(il)
hl = keras.layers.Dense(64, activation='relu',)(il)

ol = keras.layers.Dense(2, activation='softmax')(hl)

# 모델 시작 끝 지정
model = keras.models.Model(il, ol)

# 컴파일
model.compile(loss='binary_crossentropy', metrics=['accuracy'],
              optimizer='adam')

# 요약
model.summary()

model.fit
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 561)]             0
#
#  dense_5 (Dense)             (None, 64)                35968
#
#  dense_6 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 36,098
# Trainable params: 36,098
# Non-trainable params: 0
# _________________________________________________________________
# <bound method Model.fit of <keras.engine.functional.Functional object at 0x7f09a0274df0>>

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
es = EarlyStopping(monitor='val_loss',
                   min_delta=0,                
                   patience=5,                 
                   verbose=1,
                   restore_best_weights=True)

# %%
model.fit(train_X, train_Y2, validation_split=0.2, epochs=1000, callbacks=[es])
# Out:
# Epoch 1/1000
# 118/118 [==============================] - 1s 4ms/step - loss: 1.7079e-08 - accuracy: 1.0000 - val_loss: 1.5595e-08 - val_accuracy: 1.0000
# Epoch 2/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5569e-08 - accuracy: 1.0000 - val_loss: 1.2749e-08 - val_accuracy: 1.0000
# Epoch 3/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4631e-08 - accuracy: 1.0000 - val_loss: 1.1929e-08 - val_accuracy: 1.0000
# Epoch 4/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4275e-08 - accuracy: 1.0000 - val_loss: 1.2291e-08 - val_accuracy: 1.0000
# Epoch 5/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.3258e-08 - accuracy: 1.0000 - val_loss: 1.1883e-08 - val_accuracy: 1.0000
# Epoch 6/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.2333e-08 - accuracy: 1.0000 - val_loss: 1.0722e-08 - val_accuracy: 1.0000
# Epoch 7/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.2009e-08 - accuracy: 1.0000 - val_loss: 1.0630e-08 - val_accuracy: 1.0000
# Epoch 8/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.0857e-08 - accuracy: 1.0000 - val_loss: 1.1152e-08 - val_accuracy: 1.0000
# Epoch 9/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.0799e-08 - accuracy: 1.0000 - val_loss: 1.0681e-08 - val_accuracy: 1.0000
# Epoch 10/1000
# 118/118 [==============================] - 0s 2ms/step - loss: 1.0176e-08 - accuracy: 1.0000 - val_loss: 9.4345e-09 - val_accuracy: 1.0000
# Epoch 11/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 9.4245e-09 - accuracy: 1.0000 - val_loss: 8.5317e-09 - val_accuracy: 1.0000
# Epoch 12/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 8.9359e-09 - accuracy: 1.0000 - val_loss: 8.1355e-09 - val_accuracy: 1.0000
# Epoch 13/1000
# 118/118 [==============================] - 0s 2ms/step - loss: 8.4019e-09 - accuracy: 1.0000 - val_loss: 8.1501e-09 - val_accuracy: 1.0000
# Epoch 14/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 7.9331e-09 - accuracy: 1.0000 - val_loss: 7.9322e-09 - val_accuracy: 1.0000
# Epoch 15/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 7.6378e-09 - accuracy: 1.0000 - val_loss: 7.3992e-09 - val_accuracy: 1.0000
# Epoch 16/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 7.2035e-09 - accuracy: 1.0000 - val_loss: 7.2416e-09 - val_accuracy: 1.0000
# Epoch 17/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 6.9448e-09 - accuracy: 1.0000 - val_loss: 6.1666e-09 - val_accuracy: 1.0000
# Epoch 18/1000
# 118/118 [==============================] - 0s 3ms/step - loss:
1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.9100e-10 - accuracy: 1.0000 - val_loss: 3.1047e-10 - val_accuracy: 1.0000
# Epoch 156/1000
# 118/118 [==============================] - 1s 6ms/step - loss: 1.8930e-10 - accuracy: 1.0000 - val_loss: 2.9925e-10 - val_accuracy: 1.0000
# Epoch 157/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.8625e-10 - accuracy: 1.0000 - val_loss: 2.9554e-10 - val_accuracy: 1.0000
# Epoch 158/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.8490e-10 - accuracy: 1.0000 - val_loss: 2.9780e-10 - val_accuracy: 1.0000
# Epoch 159/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.8307e-10 - accuracy: 1.0000 - val_loss: 2.9606e-10 - val_accuracy: 1.0000
# Epoch 160/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.8357e-10 - accuracy: 1.0000 - val_loss: 2.8934e-10 - val_accuracy: 1.0000
# Epoch 161/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7989e-10 - accuracy: 1.0000 - val_loss: 2.8299e-10 - val_accuracy: 1.0000
# Epoch 162/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7825e-10 - accuracy: 1.0000 - val_loss: 2.8263e-10 - val_accuracy: 1.0000
# Epoch 163/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7665e-10 - accuracy: 1.0000 - val_loss: 2.7953e-10 - val_accuracy: 1.0000
# Epoch 164/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7490e-10 - accuracy: 1.0000 - val_loss: 2.7729e-10 - val_accuracy: 1.0000
# Epoch 165/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7415e-10 - accuracy: 1.0000 - val_loss: 2.7051e-10 - val_accuracy: 1.0000
# Epoch 166/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7217e-10 - accuracy: 1.0000 - val_loss: 2.7074e-10 - val_accuracy: 1.0000
# Epoch 167/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7058e-10 - accuracy: 1.0000 - val_loss: 2.7107e-10 - val_accuracy: 1.0000
# Epoch 168/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.6976e-10 - accuracy: 1.0000 - val_loss: 2.6574e-10 - val_accuracy: 1.0000
# Epoch 169/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.6803e-10 - accuracy: 1.0000 - val_loss: 2.6346e-10 - val_accuracy: 1.0000
# Epoch 170/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.6704e-10 - accuracy: 1.0000 - val_loss: 2.6081e-10 - val_accuracy: 1.0000
# Epoch 171/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.6578e-10 - accuracy: 1.0000 - val_loss: 2.5891e-10 - val_accuracy: 1.0000
# Epoch 172/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.6516e-10 - accuracy: 1.0000 - val_loss: 2.5617e-10 - val_accuracy: 1.0000
# Epoch 173/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.6308e-10 - accuracy: 1.0000 - val_loss: 2.5099e-10 - val_accuracy: 1.0000
# Epoch 174/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.6207e-10 - accuracy: 1.0000 - val_loss: 2.5094e-10 - val_accuracy: 1.0000
# Epoch 175/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5977e-10 - accuracy: 1.0000 - val_loss: 2.5286e-10 - val_accuracy: 1.0000
# Epoch 176/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5944e-10 - accuracy: 1.0000 - val_loss: 2.4946e-10 - val_accuracy: 1.0000
# Epoch 177/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5810e-10 - accuracy: 1.0000 - val_loss: 2.4759e-10 - val_accuracy: 1.0000
# Epoch 178/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5721e-10 - accuracy: 1.0000 - val_loss: 2.4356e-10 - val_accuracy: 1.0000
# Epoch 179/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5545e-10 - accuracy: 1.0000 - val_loss: 2.4130e-10 - val_accuracy: 1.0000
# Epoch 180/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5457e-10 - accuracy: 1.0000 - val_loss: 2.3891e-10 - val_accuracy: 1.0000
# Epoch 181/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.5437e-10 - accuracy: 1.0000 - val_loss: 2.3807e-10 - val_accuracy: 1.0000
# Epoch 182/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.5305e-10 - accuracy: 1.0000 - val_loss: 2.3566e-10 - val_accuracy: 1.0000
# Epoch 183/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.5141e-10 - accuracy: 1.0000 - val_loss: 2.3561e-10 - val_accuracy: 1.0000
# Epoch 184/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.5086e-10 - accuracy: 1.0000 - val_loss: 2.3039e-10 - val_accuracy: 1.0000
# Epoch 185/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.4980e-10 - accuracy: 1.0000 - val_loss: 2.3210e-10 - val_accuracy: 1.0000
# Epoch 186/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4822e-10 - accuracy: 1.0000 - val_loss: 2.3057e-10 - val_accuracy: 1.0000
# Epoch 187/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4752e-10 - accuracy: 1.0000 - val_loss: 2.2894e-10 - val_accuracy: 1.0000
# Epoch 188/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4667e-10 - accuracy: 1.0000 - val_loss: 2.2993e-10 - val_accuracy: 1.0000
# Epoch 189/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.4558e-10 - accuracy: 1.0000 - val_loss: 2.2434e-10 - val_accuracy: 1.0000
# Epoch 190/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.4481e-10 - accuracy: 1.0000 - val_loss: 2.2459e-10 - val_accuracy: 1.0000
# Epoch 191/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4363e-10 - accuracy: 1.0000 - val_loss: 2.2159e-10 - val_accuracy: 1.0000
# Epoch 192/1000
# 118/118 [==============================] - 0s 4ms/step - loss: 1.4290e-10 - accuracy: 1.0000 - val_loss: 2.2133e-10 - val_accuracy: 1.0000
# Epoch 193/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4185e-10 - accuracy: 1.0000 - val_loss: 2.1946e-10 - val_accuracy: 1.0000
# Epoch 194/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4173e-10 - accuracy: 1.0000 - val_loss: 2.1572e-10 - val_accuracy: 1.0000
# Epoch 195/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4053e-10 - accuracy: 1.0000 - val_loss: 2.1682e-10 - val_accuracy: 1.0000
# Epoch 196/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.4004e-10 - accuracy: 1.0000 - val_loss: 2.1702e-10 - val_accuracy: 1.0000
# Epoch 197/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.3914e-10 - accuracy: 1.0000 - val_loss: 2.1580e-10 - val_accuracy: 1.0000
# Epoch 198/1000
# 118/118 [==============================] - 0s 3ms/step - loss: 1.3806e-10 - accuracy: 1.0000 - val_loss: 2.1628e-10 - val_accuracy: 1.0000
# Epoch 199/1000
# 103/118 [=========================>....] - ETA: 0s - loss: 1.3269e-10 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 194.
# 118/118 [==============================] - 0s 3ms/step - loss: 1.3786e-10 - accuracy: 1.0000 - val_loss: 2.1645e-10 - val_accuracy: 1.0000
# Epoch 199: early stopping

# %% [markdown]
# ### (2) 단계2-1 : 정적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 정적 행동(Laying, Sitting, Standing)인 데이터 추출
#     * Laying, Sitting, Standing 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
stop = ['LAYING', 'SITTING', 'STANDING']

# %%
data_stop = data[data[target].isin(stop)]

# %%
data_stop[target].value_counts()
# Out:
# LAYING      1115
# STANDING    1087
# SITTING     1032
# Name: Activity, dtype: int64

# %%
data_stop[target] = data_stop[target].replace('STANDING', 2)
data_stop[target] = data_stop[target].replace('SITTING', 1)
data_stop[target] = data_stop[target].replace('LAYING', 0)

# %%
sX = data_stop.drop(target, axis=1)
sY = data_stop[target]

# %%
data_stop[target]

# %%
train_sX, val_sX, train_sY, val_sY=\
    train_test_split(sX, sY, stratify=sY, random_state=42, test_size=0.2)

# %%
sclass_n = len(set(train_sY))

train_sY = to_categorical(train_sY, sclass_n)
val_sY = to_categorical(val_sY, sclass_n)

# %%
train_sX.shape
# Out:
# (2587, 562)

# %%
# 세션 클리어
keras.backend.clear_session()

# 레이어 엮기
il = keras.layers.Input(shape=(562,))

hl = keras.layers.Dense(256, activation='relu',)(il)
hl = keras.layers.Dense(256, activation='relu',)(il)
hl = keras.layers.Dense(128, activation='relu',)(il)
hl = keras.layers.Dense(64, activation='relu',)(il)

ol = keras.layers.Dense(3, activation='softmax')(hl)

# 모델 시작 끝 지정
model_s = keras.models.Model(il, ol)

# 컴파일
model_s.compile(loss='categorical_crossentropy', metrics=['accuracy'],
              optimizer='adam')

# 요약
model_s.summary()

model_s.fit(train_sX, train_sY, validation_split=0.2, epochs=1000, callbacks=[es])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 562)]             0
#
#  dense_3 (Dense)             (None, 64)                36032
#
#  dense_4 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 36,227
# Trainable params: 36,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 65/65 [==============================] - 1s 6ms/step - loss: 0.6655 - accuracy: 0.7487 - val_loss: 0.4400 - val_accuracy: 0.8784
# Epoch 2/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.3441 - accuracy: 0.8821 - val_loss: 0.3332 - val_accuracy: 0.8649
# Epoch 3/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.2605 - accuracy: 0.9043 - val_loss: 0.2577 - val_accuracy: 0.8919
# Epoch 4/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.2099 - accuracy: 0.9251 - val_loss: 0.2336 - val_accuracy: 0.9054
# Epoch 5/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.1977 - accuracy: 0.9207 - val_loss: 0.2182 - val_accuracy: 0.9015
# Epoch 6/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.1634 - accuracy: 0.9396 - val_loss: 0.1824 - val_accuracy: 0.9228
# Epoch 7/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.1658 - accuracy: 0.9294 - val_loss: 0.1693 - val_accuracy: 0.9286
# Epoch 8/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.1658 - accuracy: 0.9304 - val_loss: 0.1598 - val_accuracy: 0.9344
# Epoch 9/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.9526 - val_loss: 0.1554 - val_accuracy: 0.9305
# Epoch 10/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9594 - val_loss: 0.1498 - val_accuracy: 0.9421
# Epoch 11/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 0.9560 - val_loss: 0.1348 - val_accuracy: 0.9440
# Epoch 32/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0717 - accuracy: 0.9754 - val_loss: 0.1374 - val_accuracy: 0.9459
# Epoch 33/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9763 - val_loss: 0.1144 - val_accuracy: 0.9498
# Epoch 34/1000
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9749 - val_loss: 0.1109 - val_accuracy: 0.9498
# Epoch 35/1000
# 51/65 [======================>.......] - ETA: 0s - loss: 0.0683 - accuracy: 0.9761Restoring model weights from the end of the best epoch: 30.
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9773 - val_loss: 0.1221 - val_accuracy: 0.9479
# Epoch 35: early stopping

# %% [markdown]
# ### (3) 단계2-2 : 동적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 동동적 행동(Walking, Walking Upstairs, Walking Downstairs)인 데이터 추출
#     * Walking, Walking Upstairs, Walking Downstairs 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
move = ['WALKING', 'WALKING_DOWNSTAIRS', 'WALKING_UPSTAIRS']

# %%
data_move = data[data[target].isin(move)]

# %%
data_move[target].value_counts()
# Out:
# WALKING               998
# WALKING_UPSTAIRS      858
# WALKING_DOWNSTAIRS    791
# Name: Activity, dtype: int64

# %%
data_move[target] = data_move[target].replace('WALKING', 0)
data_move[target] = data_move[target].replace('WALKING_DOWNSTAIRS', 1)
data_move[target] = data_move[target].replace('WALKING_UPSTAIRS', 2)

# %%
mX = data_move.drop(target, axis=1)
mY = data_move[target]

# %%
data_move[target]

# %%
train_mX, val_mX, train_mY, val_mY =\
  train_test_split(mX, mY, stratify = mY, random_state = 42, test_size= 0.2)

# %%
mclass_n = len(set(train_mY))

train_mY = to_categorical(train_mY, mclass_n)
val_mY = to_categorical(val_mY, mclass_n)

# %%
val_mY

# %%
# 세션 클리어
keras.backend.clear_session()

# 레이어 엮기
il = keras.layers.Input(shape=(562,))

hl = keras.layers.Dense(256, activation='relu',)(il)
hl = keras.layers.Dense(256, activation='relu',)(il)
hl = keras.layers.Dense(128, activation='relu',)(il)
hl = keras.layers.Dense(64, activation='relu',)(il)

ol = keras.layers.Dense(3, activation='softmax')(hl)

# 모델 시작 끝 지정
model_m = keras.models.Model(il, ol)

# 컴파일
model_m.compile(loss='categorical_crossentropy', metrics=['accuracy'],
              optimizer='adam')

# 요약
model_m.summary()

model_m.fit(train_mX, train_mY, validation_split=0.2, epochs=1000, callbacks=[es])

# %% [markdown]
# * 세부 요구사항
#     * 두 단계 모델을 통합하고, 새로운 데이터(test)에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
#     * 데이터 파이프라인 구축 : test데이터가 로딩되어 전처리 과정을 거치고, 예측 및 성능 평가 수행

# %% [markdown]
# ![](https://github.com/DA4BAM/image/blob/main/pipeline%20function.png?raw=true)

# %% [markdown]
# #### 1) 함수 만들기

# %%
model_m.fit(train_mX, train_mY, validation_split=0.2, epochs=1000, callbacks=[es])
